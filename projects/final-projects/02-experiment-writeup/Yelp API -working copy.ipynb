# %%
# working copy
# version 1, step 1: get it to run using city-based locations

import rauth
import time
import pandas as pd

def main():
    #locations = [(39.98,-82.98),(42.24,-83.61),(41.33,-89.13)]
    api_calls = []
    #for lat,long in locations:
    params = get_search_parameters()
    api_calls.append(get_results(params))    
    time.sleep(1.0)   #Be a good internet citizen and rate-limit yourself
    ##Do other processing
    print(api_calls)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
        
def get_search_parameters():
    #See the Yelp API for more details
    params = {}
    params["location"]= "San Francisco Bay Area"
    params["category_filter"] = "restaurants"
    params["radius_filter"] = "40000"
    #params["offset"] = offset
    #params["limit"] = "100"

    return params

if __name__=="__main__":
    main()
# Out:
# [{'total': 11330, 'region': {'center': {'latitude': 37.6574649, 'longitude': -122.15818359107101}, 'span': {'longitude_delta': 0.45364155964378483, 'latitude_delta': 0.37989358000000095}}, 'businesses': [{'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png', 'display_phone': '+1-510-839-0000', 'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/y8e1RATEMiDovPZZSqj1aQ/ms.jpg', 'review_count': 879, 'menu_date_updated': 1472866427, 'snippet_text': 'This place is the bomb. Not the healthiest meal in the world, but SOOO good. The grilled chicken tacos are the bomb (I get them on corn tortillas because...', 'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png', 'menu_provider': 'single_platform', 'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png', 'categories': [['Burgers', 'burg
# ...

# %%
# working copy
# version 1, step 2: make the output more readable, by putting the data into a DataFame

import rauth
import time
import pandas as pd

def main():
    #locations = [(39.98,-82.98),(42.24,-83.61),(41.33,-89.13)]
    api_calls = []
    #for lat,long in locations:
    params = get_search_parameters()
    api_calls.append(get_results(params))    
    time.sleep(1.0)   #Be a good internet citizen and rate-limit yourself
    ##Do other processing
    print(api_calls)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
        
def get_search_parameters():
    #See the Yelp API for more details
    params = {}
    params["location"] = "san francisco"
    params["category_filter"] = "cafes"
    params["radius_filter"] = "40000"
    params["limit"] = "10"

    return params

#if __name__=="__main__":
    #main()

# %%
get_search_parameters()
# Out:
# {'category_filter': 'cafes',
#  'limit': '10',
#  'location': 'san francisco',
#  'radius_filter': '40000'}

# %%
params = get_search_parameters()
#list = get_results(params)
#df = pd.DataFrame(list)
#df.head(1)
list_bus = get_results(params)['businesses']
df_bus = pd.DataFrame(list_bus)
df_bus.head(1)
# Out:
#                                           categories    display_phone  \
# 0  [[Cafes, cafes], [Coffee & Tea, coffee], [Tea ...  +1-415-742-5545
#
#                                 id  \
# 0  greenhouse-cafe-san-francisco-2
#
#                                            image_url is_claimed is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/yP7Gze...       True     False
#
#                                             location  menu_date_updated  \
# 0  {'postal_code': '94127', 'display_address': ['...       1.472591e+09
#
#      menu_provider                                         mobile_url  \
# 0  single_platform  https://m.yelp.com/biz/greenhouse-cafe-san-fra...
#
#               name       phone  rating  \
# 0  Greenhouse Cafe  4157425545     4.0
#
#                                       rating_img_url  \
# 0  https://s3-media4.fl.yelpcdn.com/assets/2/www/...
#
#                                 rating_img_url_large  \
# ...

# %%
list_bus_trimmed = get_results(params)['businesses']
df_trimmed = pd.DataFrame(list_bus_cat)[['id','name','categories','is_closed','location','rating']]  #see http://stackoverflow.com/questions/11285613/selecting-columns
df_trimmed.head(1)
# Out:
#                                 id             name  \
# 0  greenhouse-cafe-san-francisco-2  Greenhouse Cafe
#
#                                           categories is_closed  \
# 0  [[Cafes, cafes], [Coffee & Tea, coffee], [Tea ...     False
#
#                                             location  rating
# 0  {'postal_code': '94127', 'display_address': ['...     4.0

# %%
# working copy
# version 1, step 3: return to v1s1 and add in for loop

import rauth
import time
import pandas as pd


def main():
    #locations = [(39.98,-82.98),(42.24,-83.61),(41.33,-89.13)]
    global api_calls
    api_calls = []
    offset = 0
    params = get_search_parameters()
    global total_results
    total_results = get_results(params)['total']
    while offset < total_results:
        params = get_search_parameters()
        api_calls.append(get_results(params))
        time.sleep(1.0)   #Be a good internet citizen and rate-limit yourself
        offset += 40
    ##Do other processing
    global df_bus
    df_bus = pd.DataFrame(api_calls)
    print(api_calls)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
    
def get_search_parameters():
    #See the Yelp API for more details
    global params
    params = {}
    params["location"]= "san francisco bay area"
    params["category_filter"] = "cafes"
    #params["radius_filter"] = "1"
    offset = 0
    params["offset"] = offset
    #params["limit"] = "40"

    return params

if __name__=="__main__":
    main()

#get_search_parameters() #this works fine
#get_results(params)
#get_results(params)

#get_results(params)
#return get_results(params)['total']
# Out:
# [{'region': {'span': {'longitude_delta': 0.6707132299999898, 'latitude_delta': 0.7926621505311289}, 'center': {'latitude': 37.61253097751415, 'longitude': -122.21129395}}, 'businesses': [{'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/E56LlbZsZobGyTBNkC6uXA/ms.jpg', 'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png', 'location': {'display_address': ['213 Stage Rd', 'Pescadero, CA 94060'], 'coordinate': {'latitude': 37.25223, 'longitude': -122.38345}, 'city': 'Pescadero', 'geo_accuracy': 8.0, 'address': ['213 Stage Rd'], 'state_code': 'CA', 'country_code': 'US', 'postal_code': '94060'}, 'display_phone': '+1-650-879-9155', 'id': 'downtown-local-pescadero-2', 'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png', 'review_count': 89, 'is_claimed': True, 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F6GLaZJQK9fjQYO3xcXOLQ/ms
# ...

# %%
total_results
# Out:
# 868

# %%
df_bus = pd.DataFrame(api_calls)['businesses'][1]
df_bus
# Out:
# [{'categories': [['Cafes', 'cafes'], ['Coffee & Tea', 'coffee']],
#   'display_phone': '+1-650-879-9155',
#   'id': 'downtown-local-pescadero-2',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F6GLaZJQK9fjQYO3xcXOLQ/ms.jpg',
#   'is_claimed': True,
#   'is_closed': False,
#   'location': {'address': ['213 Stage Rd'],
#    'city': 'Pescadero',
#    'coordinate': {'latitude': 37.25223, 'longitude': -122.38345},
#    'country_code': 'US',
#    'display_address': ['213 Stage Rd', 'Pescadero, CA 94060'],
#    'geo_accuracy': 8.0,
#    'postal_code': '94060',
#    'state_code': 'CA'},
#   'mobile_url': 'https://m.yelp.com/biz/downtown-local-pescadero-2?adjust_creative=bVSKbqU28-0odouNJ4bWwA&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=bVSKbqU28-0odouNJ4bWwA',
#   'name': 'Downtown Local',
#   'phone': '6508799155',
#   'rating': 4.5,
#   'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
# ...

# %%
df_bus.head(1)
# Out:
# 0    [{'snippet_image_url': 'https://s3-media1.fl.y...
# Name: businesses, dtype: object

# %%
# just the totals by category for each zipcode

import rauth
import time
import pandas as pd


def main():
    locations = ["94002", "94005", "94010", "94011", "94013", "94014", "94015", "94016", "94017", "94018", "94103"]
    global api_calls
    #api_calls = []
    global total_results_list
    total_results_list = []
    offset = 0
    params = get_search_parameters()
    global total_results
    #total_results = get_results(params)['total']
    #while offset < total_results:
    for zip in locations:
        params = get_search_parameters()
        params["location"] = zip
        total_results = get_results(params)['total']
        total_results_list.append(get_results(params)['total'])
        #api_calls.append(get_results(params))
        #time.sleep(1.0)
        #offset += 40
    ##Do other processing
    global df_bus
    df_bus = pd.DataFrame(api_calls)
    #print(api_calls)
    print (total_results_list)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
    
def get_search_parameters():
    #See the Yelp API for more details
    global params
    params = {}
    #params["location"] = "locations"
    params["category_filter"] = "cafes"
    params["radius_filter"] = "1600"
    #offset = 0
    #params["offset"] = offset
    #params["limit"] = "40"

    return params

if __name__=="__main__":
    main()
# Out:
# [0, 0, 6, 3, 0, 0, 1, 1, 2, 0, 59]

# %%
# I only need totals per zip

import rauth
import time
import pandas as pd


def main():
    #categories = ['cafes','bakeries','deptstores','montessori','collegeuniv','privateschools','funeralservices']
    #categories = ['cafes','bakeries','deptstores']
    locations = ["94002", "94005", "94010", "94011", "94013"]
    global api_calls
    #api_calls = []
    global total_results_list
    total_results_list = []
    offset = 0
    params = get_search_parameters()
    global total_results
    #total_results = get_results(params)['total']
    #while offset < total_results:
    for zip in locations:
        params = get_search_parameters()
        params["location"] = zip
        total_results = get_results(params)['total']
        total_results_list.append(get_results(params)['total'])
        #api_calls.append(get_results(params))
        #time.sleep(1.0)
        #offset += 40
    ##Do other processing
    global df_bus
    df_bus = pd.DataFrame(api_calls)
    #print(api_calls)
    print (total_results_list)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
    
def get_search_parameters():
    #See the Yelp API for more details
    global params
    params = {}
    #params["location"] = "locations"
    params["category_filter"] = "cafes"
    params["radius_filter"] = "1600"
    #offset = 0
    #params["offset"] = offset
    #params["limit"] = "40"

    return params

if __name__=="__main__":
    main()
# Out:
# [0, 0, 6, 3, 0]

# %%
# And then I need categories by zip

import rauth
import time
import pandas as pd


def main():
    #categories = ['cafes','bakeries','deptstores','montessori','collegeuniv','privateschools','funeralservices']
    categories = ['cafes','bakeries','deptstores']
    locations = ["94002", "94005", "94010", "94011", "94103"]
    global api_calls
    #api_calls = []
    global total_results_list
    total_results_list = []
    global subtotal_results_list
    subtotal_results_list = []
    offset = 0
    params = get_search_parameters()
    global total_results
    #total_results = get_results(params)['total']
    #while offset < total_results:
    for cats in categories:
        params = get_search_parameters()
        params["category_filter"] = cats
        subtotal_results_list = []  
        for zip in locations:
            params["location"] = zip
            subtotal_results = get_results(params)['total']
            subtotal_results_list.append(get_results(params)['total'])
            #api_calls.append(get_results(params))
            #time.sleep(1.0)
            #offset += 40            
        #total_results = get_results(params)['total']
        total_results_list.append(subtotal_results_list)

    ##Do other processing
    global df_bus
    df_bus = pd.DataFrame(api_calls)
    #print(api_calls)
    print (total_results_list)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
    
def get_search_parameters():
    #See the Yelp API for more details
    global params
    params = {}
    #params["location"] = "locations"
    #params["category_filter"] = "cafes"
    params["radius_filter"] = "1600"
    #offset = 0
    #params["offset"] = offset
    #params["limit"] = "40"

    return params

if __name__=="__main__":
    main()
# Out:
# [[1, 5, 6, 5, 71], [0, 0, 6, 3, 59], [0, 0, 0, 0, 19]]

# %%
# rearranging the matrix so that instead of zips by categories, it's categories by zips

import rauth
import time
import pandas as pd


def main():
    #categories = ['bakeries','cafes','deptstores','montessori','collegeuniv','privateschools','funeralservices']
    global search_term
    #term = ["starbucks","subway","mcdonald's"]
    global categories
    categories = ["cafes"] #test categories
    #categories = ["cafes","bakeries","deptstores","fitness","dentists"]
    global locations
    #locations = ["94002", "94005", "94010", "94011", "94103"] #test locations
    locations = ["94002", "94005", "94010", "94011", "94013", "94014", "94015", "94016", "94017", "94018", "94019", "94020", "94021", "94022", "94023", "94024", "94025", "94026", "94027", "94028", "94030", "94035", "94037", "94038", "94039", "94040", "94041", "94042", "94043", "94044", "94060", "94061", "94062", "94063", "94064", "94065", "94066", "94070", "94074", "94080", "94083", "94085", "94086", "94087", "94088", "94089", "94096", "94098"]#, "94101", "94102", "94103", "94104", "94105", "94106", "94107", "94108", "94109", "94110", "94111", "94112", "94114", "94115", "94116", "94117", "94118", "94119", "94120", "94121", "94122", "94123", "94124", "94125", "94126
", "95126", "95127", "95128", "95129", "95130", "95131", "95132", "95133", "95134", "95135", "95136", "95138", "95139", "95140", "95141", "95148", "95150", "95151", "95152", "95153", "95154", "95155", "95156", "95157", "95158", "95159", "95160", "95161", "95164", "95170", "95172", "95173", "95190", "95191", "95192", "95193", "95194", "95196", "95401", "95402", "95403", "95404", "95405", "95406", "95407", "95408", "95409", "95412", "95416", "95419", "95421", "95425", "95430", "95431", "95433", "95436", "95439", "95441", "95442", "95444", "95446", "95448", "95450", "95452", "95462", "95465", "95471", "95472", "95473", "95476", "95480", "95486", "95487", "95492", "95497", "95620", "95625", "95687", "95688", "95696"]
    global api_calls
    #api_calls = []
    global total_results_list
    total_results_list = []
    global subtotal_results_list
    subtotal_results_list = []
    offset = 0
    params = get_search_parameters()
    global total_results
    #total_results = get_results(params)['total']
    #while offset < total_results:

    for zips in locations:
        params = get_search_parameters()
        params["location"] = zips
        subtotal_results_list = []
        for cats in categories:
            params["category_filter"] = cats
            subtotal_results = get_results(params)['total']
            subtotal_results_list.append(get_results(params)['total'])            
            #api_calls.append(get_results(params))
            #time.sleep(1.0)
            #offset += 40            
        #total_results = get_results(params)['total']
        total_results_list.append(subtotal_results_list)            

    ##Do other processing
    global df_bus
    df_bus = pd.DataFrame(api_calls)
    #print(api_calls)
    print (total_results_list)

def get_results(params):

    #Obtain these from Yelp's manage access page
    consumer_key = "bVSKbqU28-0odouNJ4bWwA"
    consumer_secret = "uAfty-ZKj5Wu8VeNE8y3Z4aIdmA"
    token = "Sa3F9pBstCcgMIJxZ4guMJ1TcoPtGxCm"
    token_secret = "m2nzjxN4vw6iDGOzjoohZDi906c"
    
    session = rauth.OAuth1Session(
        consumer_key = consumer_key
        ,consumer_secret = consumer_secret
        ,access_token = token
        ,access_token_secret = token_secret)
        
    request = session.get("http://api.yelp.com/v2/search",params=params)
    
    #Transforms the JSON API response into a Python dictionary
    data = request.json()
    session.close()
    
    return data
    
def get_search_parameters():
    #See the Yelp API for more details
    global params
    params = {}
    #params["location"] = "locations"
    #params["category_filter"] = "cafes"
    params["radius_filter"] = "1600"
    #offset = 0
    #params["offset"] = offset
    #params["limit"] = "40"

    return params

if __name__=="__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-7d3ff6d10a36> in <module>()
#      85
#      86 if __name__=="__main__":
# ---> 87     main()
#
# <ipython-input-103-7d3ff6d10a36> in main()
#      35         for cats in categories:
#      36             params["category_filter"] = cats
# ---> 37             subtotal_results = get_results(params)['total']
#      38             subtotal_results_list.append(get_results(params)['total'])
#      39             #api_calls.append(get_results(params))
#
# KeyError: 'total'

# %%
print (categories)
print (locations)
print (total_results_list)
# Out:
# ['bakeries', 'cafes', 'deptstores']
# ['94002', '94005', '94010', '94011', '94103']
# [[1, 0, 0], [5, 0, 0], [6, 6, 0], [5, 3, 0], [71, 59, 19]]

# %%
df_subtotals = pd.DataFrame(total_results_list, index=locations, columns=categories)

# %%
df_subtotals
# Out:
#        bakeries  cafes  deptstores
# 94002         1      0           0
# 94005         5      0           0
# 94010         6      6           0
# 94011         5      3           0
# 94103        71     59          19
